# %%
import pandas as pd
import numpy as np

# Importing the XGBoost classifier we shall use later.
import xgboost as xgb
from xgboost import XGBClassifier


from imblearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.model_selection import StratifiedKFold, cross_validate, RandomizedSearchCV
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score, roc_auc_score,
    make_scorer, balanced_accuracy_score
)


from scipy.stats import randint, uniform, norm
from sklearn.metrics import fbeta_score

# %%
# Loading the names for entibiotics, and reading their files.
antibiotics = ['Gentamicin', 'Trimethoprim_Sulfamethoxazole', 'Ciprofloxacin',
                'Ampicillin', 'Cefazolin','Nitrofurantoin','Piperacillin_Tazobactam',
                'Levofloxacin', 'Ceftriaxone']

# Fix a random state for reproducability.
n_randstat = 312

# %%
# Load and prepare data

for anti in antibiotics:

    all_results = []      #Creating dataframe to store model measurement results later.

    train_df = pd.read_csv(
        f"Final_dataframe-20251015T154934Z-1-001\\Final_dataframe\\{anti}_train_data.csv"
    )

    X = train_df.drop(columns=[anti, 'Year', 'anon_id'])
    y = train_df[anti] - 1  # Convert {1,2} to {0,1}


    # Calculating the positive/negative weight of our target variable set, which shall be used in XGBoost to counter the high imbalance of some antibiotic data.
    neg_count = np.sum(y == 0)
    pos_count = np.sum(y == 1)
    scale_pos_weight_value = neg_count / pos_count 



    # Define base pipeline  
    # Note: for XGBoost, we do not need employ Standard Scaler.
    base_pipeline = Pipeline([
        ('xgb', XGBClassifier(
            objective='binary:logistic',
            eval_metric='auc',
            random_state=n_randstat
        ))
    ])

    
    # Hyperparameter space for random parameter search.
    param_distributions = {
        'xgb__n_estimators': randint(300, 400),      
        'xgb__learning_rate': uniform(0.05, 0.20),   
        'xgb__max_depth': randint(3, 5),
        'xgb__subsample': uniform(0.3, 0.7),
        'xgb__colsample_bytree': uniform(0.3, 0.7),
        'xgb__gamma': uniform(0.1, 1),
        'xgb__scale_pos_weight': [1,0.25*scale_pos_weight_value, 0.5*scale_pos_weight_value, 0.75*scale_pos_weight_value, scale_pos_weight_value]       
    }


    # Scoring setup (all using Fβ)
    scoring = {
        'accuracy': make_scorer(accuracy_score, zero_division=0),
        'recall': make_scorer(recall_score, zero_division=0),         # Maximizing recall is equivalent to minimizing fall negative rate, as they always sum up to be 1.
        'precision': make_scorer(precision_score, zero_division=0),
        'f1': make_scorer(f1_score, average = 'weighted', zero_division=0),      # Using weighted F1 score for model evaluation.
        'balanced_accuracy': make_scorer(balanced_accuracy_score, zero_division = 0),
    
    }



    # Nested CV setup
    outer_cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=n_randstat)    # Outer 5-fold loop for cross-validation.
    inner_cv = StratifiedKFold(n_splits=3, shuffle=True, random_state=n_randstat)    # Inner 3-fold loop for hyper-parameter tuning.

    outer_results = []
    outer_fold = 1

    for train_idx, test_idx in outer_cv.split(X, y):                         # Outer 5-fold loop for cross-validation.
        print(f"\n==============================")
        print(f"🔹 Outer Fold {outer_fold} — training inner search for {anti}")
        print(f"==============================")

        X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
        y_train, y_test = y.iloc[train_idx], y.iloc[test_idx]

        # ---- Inner hyperparameter tuning ----
        search = RandomizedSearchCV(                      # Defining the randomized searching module.
            estimator=base_pipeline,
            param_distributions=param_distributions,
            n_iter= 10,     # Iteration time for randomized searching.
            scoring= 'f1',  # using weighted f1 for optimization
            cv=inner_cv,    # Using a inner 3-fold for hyper-parameter tuning.
            random_state=n_randstat
        )

        search.fit(X_train, y_train)

        print("Best inner parameters:", search.best_params_)
        print(f"Best inner score:", search.best_score_)



        # ---- Evaluate on outer fold ----
        best_model = search.best_estimator_
        y_pred = best_model.predict(X_test)

        accuracy = accuracy_score(y_test, y_pred)
        recall = recall_score(y_test, y_pred, zero_division=0)
        precision = precision_score(y_test, y_pred, zero_division=0)
        f1 = f1_score(y_test, y_pred, average='weighted', zero_division=0)
        fnr = 1 - recall

        outer_results.append({
            'fold': outer_fold,
            'best_params': search.best_params_,
            'precision': precision,
            'recall': recall,
            'f1': f1,
            'accuracy': accuracy,
            'FNR': fnr
        })

        outer_fold += 1    
    

    # Aggregate final performance
    outer_df = pd.DataFrame(outer_results)
    print(f"\n\n===== Nested CV Summary for {anti}=====")
    print(outer_df[['fold', 'recall', 'f1', 'FNR']])
    print("Mean Accuracy:", outer_df['accuracy'].mean())
    print("Mean Recall:", outer_df['recall'].mean())                
    print(f"Mean F1:", outer_df['f1'].mean())
    print("Mean false negative rate:", outer_df['FNR'].mean())

    # Save per-antibiotic result CSV
    output_path = f"results_{anti}.csv"
    outer_df.to_csv(output_path, index=False)
    print(f"Saved results to {output_path}")

    # Add to results list
    all_results.append(outer_df)


# Merge all antibiotics' results together
final_df = pd.concat(all_results, ignore_index=True)
final_df.to_csv("all_antibiotics_results.csv", index=False)
print("Saved all results to all_antibiotics_results.csv")
# Out:
# ==============================
# 🔹 Outer Fold 1 — training inner search for Gentamicin
# ==============================
# Best inner parameters: {'xgb__colsample_bytree': 0.9840134829675653, 'xgb__gamma': 1.0440636313297216, 'xgb__learning_rate': 0.17903579482489707, 'xgb__max_depth': 4, 'xgb__n_estimators': 371, 'xgb__scale_pos_weight': 12.133874239350913, 'xgb__subsample': 0.3821561339972655}
# Best inner score: 0.12897892952923815
#
# ==============================
# 🔹 Outer Fold 2 — training inner search for Gentamicin
# ==============================
# Best inner parameters: {'xgb__colsample_bytree': 0.9840134829675653, 'xgb__gamma': 1.0440636313297216, 'xgb__learning_rate': 0.17903579482489707, 'xgb__max_depth': 4, 'xgb__n_estimators': 371, 'xgb__scale_pos_weight': 12.133874239350913, 'xgb__subsample': 0.3821561339972655}
# Best inner score: 0.12962730996904673
#
# ==============================
# 🔹 Outer Fold 3 — training inner search for Gentamicin
# ==============================
# Best inner parameters: {'xgb__colsample_bytree': 0.9840134829675653, 'xgb__gamma': 1.0440636313297216, 'xgb__learning_rate': 0.17903579482489707, 'xgb__max_depth': 4, 'xgb__n_estimators': 371, 'xgb__scale_pos_weight': 12.133874239350913, 'xgb__subsample': 0.3821561339972655}
# Best inner score: 0.13497885237015672
#
# ==============================
# 🔹 Outer Fold 4 — training inner search for Gentamicin
# ==============================
# Best inner parameters: {'xgb__colsample_bytree': 0.9840134829675653, 'xgb__gamma': 1.0440636313297216, 'xgb__learning_rate': 0.17903579482489707, 'xgb__max_depth': 4, 'xgb__n_estimators': 371, 'xgb__scale_pos_weight': 12.133874239350913, 'xgb__subsample': 0.3821561339972655}
# Best inner score: 0.13692581991930322
#
# ==============================
# 🔹 Outer Fold 5 — training inner search for Gentamicin
# ==============================
# Best inner parameters: {'xgb__colsample_bytree': 0.9840134829675653, 'xgb__gamma': 1.0440636313297216, 'xgb__learning_rate': 0.17903579482489707, 'xgb__max_depth': 4, 'xgb__n_estimators': 371, 'xgb__scale_pos_weight': 12.133874239350913, 'xgb__subsample': 0.3821561339972655}
# Best inner score: 0.11522301057230767
#
#
# ===== Nested CV Summary for Gentamicin=====
#    fold    recall        f1       FNR
# 0     1  0.306122  0.740469  0.693878
# 1     2  0.387755  0.737124  0.612245
# 2     3  0.363636  0.737067  0.636364
# 3     4  0.303030  0.702520  0.696970
# 4     5  0.333333  0.717061  0.666667
# Mean Accuracy: 0.6440154440154441
# Mean Recall: 0.3387755102040816
# Mean F1: 0.7268481887452455
# Mean false negative rate: 0.6612244897959185
# Saved results to results_Gentamicin.csv
#
# ==============================
# 🔹 Outer Fold 1 — training inner search for Trimethoprim_Sulfamethoxazole
# ==============================
# Best inner parameters: {'xgb__colsample_bytree': 0.9840134829675653, 'xgb__gamma': 1.0440636313297216, 'xgb__learning_rate': 0.17903579482489707, 'xgb__max_depth': 4, 'xgb__n_estimators': 371, 'xgb__scale_pos_weight': 3.375, 'xgb__subsample': 0.3821561339972655}
# Best inner score: 0.2919945375435396
#
# ==============================
# 🔹 Outer Fold 2 — training inner search for Trimethoprim_Sulfamethoxazole
# ==============================
# Exception ignored in: <function Booster.__del__ at 0x0000023CAB819B20>
# Traceback (most recent call last):
#   File "c:\Anaconda\envs\erdos_ds_environment\Lib\site-packages\xgboost\core.py", line 1797, in __del__
#     _check_call(_LIB.XGBoosterFree(self.handle))
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt:
# Best inner parameters: {'xgb__colsample_bytree': 0.9840134829675653, 'xgb__gamma': 1.0440636313297216, 'xgb__learning_rate': 0.17903579482489707, 'xgb__max_depth': 4, 'xgb__n_estimators': 371, 'xgb__scale_pos_weight': 3.375, 'xgb__subsample': 0.3821561339972655}
# Best inner score: 0.273759190541028
#
# ==============================
# 🔹 Outer Fold 3 — training inner search for Trimethoprim_Sulfamethoxazole
# ==============================
# Best inner parameters: {'xgb__colsample_bytree': 0.9840134829675653, 'xgb__gamma': 1.0440636313297216, 'xgb__learning_rate': 0.17903579482489707, 'xgb__max_depth': 4, 'xgb__n_estimators': 371, 'xgb__scale_pos_weight': 3.375, 'xgb__subsample': 0.3821561339972655}
# Best inner score: 0.3035168769511159
#
# ==============================
# 🔹 Outer Fold 4 — training inner search for Trimethoprim_Sulfamethoxazole
# ==============================
# Best inner parameters: {'xgb__colsample_bytree': 0.9840134829675653, 'xgb__gamma': 1.0440636313297216, 'xgb__learning_rate': 0.17903579482489707, 'xgb__max_depth': 4, 'xgb__n_estimators': 371, 'xgb__scale_pos_weight': 3.375, 'xgb__subsample': 0.3821561339972655}
# Best inner score: 0.2904701207308385
#
# ==============================
# 🔹 Outer Fold 5 — training inner search for Trimethoprim_Sulfamethoxazole
# ==============================
# Best inner parameters: {'xgb__colsample_bytree': 0.9840134829675653, 'xgb__gamma': 1.0440636313297216, 'xgb__learning_rate': 0.17903579482489707, 'xgb__max_depth': 4, 'xgb__n_estimators': 371, 'xgb__scale_pos_weight': 3.375, 'xgb__subsample': 0.3821561339972655}
# Best inner score: 0.28115212527964206
#
#
# ===== Nested CV Summary for Trimethoprim_Sulfamethoxazole=====
#    fold    recall        f1       FNR
# 0     1  0.385135  0.566361  0.614865
# 1     2  0.503378  0.561708  0.496622
# 2     3  0.418919  0.553491  0.581081
# 3     4  0.368243  0.609779  0.631757
# 4     5  0.351351  0.591782  0.648649
# Mean Accuracy: 0.5428571428571428
# Mean Recall: 0.40540540540540543
# Mean F1: 0.5766244897865551
# Mean false negative rate: 0.5945945945945946
# Saved results to results_Trimethoprim_Sulfamethoxazole.csv
#
# ==============================
# 🔹 Outer Fold 1 — training inner search for Ciprofloxacin
# ==============================
# Best inner parameters: {'xgb__colsample_bytree': 0.36140088883284394, 'xgb__gamma': 0.7833955197168099, 'xgb__learning_rate': 0.06769303305937369, 'xgb__max_depth': 3, 'xgb__n_estimators': 361, 'xgb__scale_pos_weight': 4.001712328767123, 'xgb__subsample': 0.7799962261085898}
# Best inner score: 0.26735710451912215
#
# ==============================
# 🔹 Outer Fold 2 — training inner search for Ciprofloxacin
# ==============================
# Best inner parameters: {'xgb__colsample_bytree': 0.36140088883284394, 'xgb__gamma': 0.7833955197168099, 'xgb__learning_rate': 0.06769303305937369, 'xgb__max_depth': 3, 'xgb__n_estimators': 361, 'xgb__scale_pos_weight': 4.001712328767123, 'xgb__subsample': 0.7799962261085898}
# Best inner score: 0.26058071491174156
#
# ==============================
# 🔹 Outer Fold 3 — training inner search for Ciprofloxacin
# ==============================
# Best inner parameters: {'xgb__colsample_bytree': 0.36140088883284394, 'xgb__gamma': 0.7833955197168099, 'xgb__learning_rate': 0.06769303305937369, 'xgb__max_depth': 3, 'xgb__n_estimators': 361, 'xgb__scale_pos_weight': 4.001712328767123, 'xgb__subsample': 0.7799962261085898}
# Best inner score: 0.26778535378678214
#
# ==============================
# 🔹 Outer Fold 4 — training inner search for Ciprofloxacin
# ==============================
# Best inner parameters: {'xgb__colsample_bytree': 0.36140088883284394, 'xgb__gamma': 0.7833955197168099, 'xgb__learning_rate': 0.06769303305937369, 'xgb__max_depth': 3, 'xgb__n_estimators': 361, 'xgb__scale_pos_weight': 4.001712328767123, 'xgb__subsample': 0.7799962261085898}
# Best inner score: 0.2832600718351681
#
# ==============================
# 🔹 Outer Fold 5 — training inner search for Ciprofloxacin
# ==============================
# Best inner parameters: {'xgb__colsample_bytree': 0.9840134829675653, 'xgb__gamma': 1.0440636313297216, 'xgb__learning_rate': 0.17903579482489707, 'xgb__max_depth': 4, 'xgb__n_estimators': 371, 'xgb__scale_pos_weight': 5.335616438356165, 'xgb__subsample': 0.3821561339972655}
# Best inner score: 0.25407588209813226
#
#
# ===== Nested CV Summary for Ciprofloxacin=====
#    fold    recall        f1       FNR
# 0     1  0.362745  0.744388  0.637255
# 1     2  0.352941  0.742086  0.647059
# 2     3  0.294118  0.740311  0.705882
# 3     4  0.331707  0.747096  0.668293
# 4     5  0.370732  0.681733  0.629268
# Mean Accuracy: 0.7085714285714285
# Mean Recall: 0.3424485891917743
# Mean F1: 0.7311228826529657
# Mean false negative rate: 0.6575514108082257
# Saved results to results_Ciprofloxacin.csv
#
# ==============================
# 🔹 Outer Fold 1 — training inner search for Ampicillin
# ==============================
# Best inner parameters: {'xgb__colsample_bytree': 0.9840134829675653, 'xgb__gamma': 1.0440636313297216, 'xgb__learning_rate': 0.17903579482489707, 'xgb__max_depth': 4, 'xgb__n_estimators': 371, 'xgb__scale_pos_weight': 1.502899110939312, 'xgb__subsample': 0.3821561339972655}
# Best inner score: 0.4265920653839374
#
# ==============================
# 🔹 Outer Fold 2 — training inner search for Ampicillin
# ==============================
# Best inner parameters: {'xgb__colsample_bytree': 0.9840134829675653, 'xgb__gamma': 1.0440636313297216, 'xgb__learning_rate': 0.17903579482489707, 'xgb__max_depth': 4, 'xgb__n_estimators': 371, 'xgb__scale_pos_weight': 1.502899110939312, 'xgb__subsample': 0.3821561339972655}
# Best inner score: 0.4128911296158096
#
# ==============================
# 🔹 Outer Fold 3 — training inner search for Ampicillin
# ==============================
# Best inner parameters: {'xgb__colsample_bytree': 0.9840134829675653, 'xgb__gamma': 1.0440636313297216, 'xgb__learning_rate': 0.17903579482489707, 'xgb__max_depth': 4, 'xgb__n_estimators': 371, 'xgb__scale_pos_weight': 1.502899110939312, 'xgb__subsample': 0.3821561339972655}
# Best inner score: 0.42128031527589765
#
# ==============================
# 🔹 Outer Fold 4 — training inner search for Ampicillin
# ==============================
# Best inner parameters: {'xgb__colsample_bytree': 0.9840134829675653, 'xgb__gamma': 1.0440636313297216, 'xgb__learning_rate': 0.17903579482489707, 'xgb__max_depth': 4, 'xgb__n_estimators': 371, 'xgb__scale_pos_weight': 1.502899110939312, 'xgb__subsample': 0.3821561339972655}
# Best inner score: 0.4394703787973848
#
# ==============================
# 🔹 Outer Fold 5 — training inner search for Ampicillin
# ==============================
# Best inner parameters: {'xgb__colsample_bytree': 0.9840134829675653, 'xgb__gamma': 1.0440636313297216, 'xgb__learning_rate': 0.17903579482489707, 'xgb__max_depth': 4, 'xgb__n_estimators': 371, 'xgb__scale_pos_weight': 1.502899110939312, 'xgb__subsample': 0.3821561339972655}
# Best inner score: 0.44676021697868223
#
#
# ===== Nested CV Summary for Ampicillin=====
#    fold    recall        f1       FNR
# 0     1  0.497099  0.522908  0.502901
# 1     2  0.381044  0.512691  0.618956
# 2     3  0.502901  0.529744  0.497099
# 3     4  0.442085  0.515996  0.557915
# 4     5  0.498069  0.492362  0.501931
# Mean Accuracy: 0.5113513513513513
# Mean Recall: 0.46423978551638123
# Mean F1: 0.5147402340448273
# Mean false negative rate: 0.5357602144836188
# Saved results to results_Ampicillin.csv
#
# ==============================
# 🔹 Outer Fold 1 — training inner search for Cefazolin
# ==============================
# Best inner parameters: {'xgb__colsample_bytree': 0.3253524923335095, 'xgb__gamma': 0.1590373696250477, 'xgb__learning_rate': 0.12871575577588695, 'xgb__max_depth': 3, 'xgb__n_estimators': 383, 'xgb__scale_pos_weight': 7.224137931034483, 'xgb__subsample': 0.9135442116320804}
# Best inner score: 0.17215109503816683
#
# ==============================
# 🔹 Outer Fold 2 — training inner search for Cefazolin
# ==============================
# Best inner parameters: {'xgb__colsample_bytree': 0.36140088883284394, 'xgb__gamma': 0.7833955197168099, 'xgb__learning_rate': 0.06769303305937369, 'xgb__max_depth': 3, 'xgb__n_estimators': 361, 'xgb__scale_pos_weight': 7.224137931034483, 'xgb__subsample': 0.7799962261085898}
# Best inner score: 0.17434163066817168
#
# ==============================
# 🔹 Outer Fold 3 — training inner search for Cefazolin
# ==============================
# Best inner parameters: {'xgb__colsample_bytree': 0.36140088883284394, 'xgb__gamma': 0.7833955197168099, 'xgb__learning_rate': 0.06769303305937369, 'xgb__max_depth': 3, 'xgb__n_estimators': 361, 'xgb__scale_pos_weight': 7.224137931034483, 'xgb__subsample': 0.7799962261085898}
# Best inner score: 0.16927044191432772
#
# ==============================
# 🔹 Outer Fold 4 — training inner search for Cefazolin
# ==============================
# Best inner parameters: {'xgb__colsample_bytree': 0.3253524923335095, 'xgb__gamma': 0.1590373696250477, 'xgb__learning_rate': 0.12871575577588695, 'xgb__max_depth': 3, 'xgb__n_estimators': 383, 'xgb__scale_pos_weight': 7.224137931034483, 'xgb__subsample': 0.9135442116320804}
# Best inner score: 0.17548318727228554
#
# ==============================
# 🔹 Outer Fold 5 — training inner search for Cefazolin
# ==============================
# Best inner parameters: {'xgb__colsample_bytree': 0.36140088883284394, 'xgb__gamma': 0.7833955197168099, 'xgb__learning_rate': 0.06769303305937369, 'xgb__max_depth': 3, 'xgb__n_estimators': 361, 'xgb__scale_pos_weight': 7.224137931034483, 'xgb__subsample': 0.7799962261085898}
# Best inner score: 0.15399224513112497
#
#
# ===== Nested CV Summary for Cefazolin=====
#    fold    recall        f1       FNR
# 0     1  0.213115  0.809711  0.786885
# 1     2  0.204918  0.816219  0.795082
# 2     3  0.196721  0.816292  0.803279
# 3     4  0.213115  0.816136  0.786885
# 4     5  0.214876  0.806303  0.785124
# Mean Accuracy: 0.7913513513513513
# Mean Recall: 0.20854897710337356
# Mean F1: 0.8129322922686766
# Mean false negative rate: 0.7914510228966265
# Saved results to results_Cefazolin.csv
#
# ==============================
# 🔹 Outer Fold 1 — training inner search for Nitrofurantoin
# ==============================
# Best inner parameters: {'xgb__colsample_bytree': 0.36140088883284394, 'xgb__gamma': 0.7833955197168099, 'xgb__learning_rate': 0.06769303305937369, 'xgb__max_depth': 3, 'xgb__n_estimators': 361, 'xgb__scale_pos_weight': 55.71802325581396, 'xgb__subsample': 0.7799962261085898}
# Best inner score: 0.03807020449706301
#
# ==============================
# 🔹 Outer Fold 2 — training inner search for Nitrofurantoin
# ==============================
# Best inner parameters: {'xgb__colsample_bytree': 0.5064543369180614, 'xgb__gamma': 0.37173034138371164, 'xgb__learning_rate': 0.20397510005039515, 'xgb__max_depth': 3, 'xgb__n_estimators': 328, 'xgb__scale_pos_weight': 18.572674418604652, 'xgb__subsample': 0.9821047615363967}
# Best inner score: 0.04509671614934773
#
# ==============================
# 🔹 Outer Fold 3 — training inner search for Nitrofurantoin
# ==============================
# Best inner parameters: {'xgb__colsample_bytree': 0.6043568570763409, 'xgb__gamma': 0.9517986223887481, 'xgb__learning_rate': 0.13543890252388407, 'xgb__max_depth': 3, 'xgb__n_estimators': 332, 'xgb__scale_pos_weight': 18.572674418604652, 'xgb__subsample': 0.9260840381883872}
# Best inner score: 0.04345783415550858
#
# ==============================
# 🔹 Outer Fold 4 — training inner search for Nitrofurantoin
# ==============================
# Best inner parameters: {'xgb__colsample_bytree': 0.4517088155379368, 'xgb__gamma': 0.518722019865265, 'xgb__learning_rate': 0.13285655883342876, 'xgb__max_depth': 3, 'xgb__n_estimators': 358, 'xgb__scale_pos_weight': 37.145348837209305, 'xgb__subsample': 0.5517190540915315}
# Best inner score: 0.04545385859135349
#
# ==============================
# 🔹 Outer Fold 5 — training inner search for Nitrofurantoin
# ==============================
# Best inner parameters: {'xgb__colsample_bytree': 0.5064543369180614, 'xgb__gamma': 0.37173034138371164, 'xgb__learning_rate': 0.20397510005039515, 'xgb__max_depth': 3, 'xgb__n_estimators': 328, 'xgb__scale_pos_weight': 18.572674418604652, 'xgb__subsample': 0.9821047615363967}
# Best inner score: 0.0546031746031746
#
#
# ===== Nested CV Summary for Nitrofurantoin=====
#    fold    recall        f1       FNR
# 0     1  0.235294  0.895873  0.764706
# 1     2  0.000000  0.963468  1.000000
# 2     3  0.000000  0.971392  1.000000
# 3     4  0.117647  0.943490  0.882353
# 4     5  0.055556  0.964364  0.944444
# Mean Accuracy: 0.9249420849420849
# Mean Recall: 0.08169934640522876
# Mean F1: 0.9477175085880031
# Mean false negative rate: 0.9183006535947712
# Saved results to results_Nitrofurantoin.csv
#
# ==============================
# 🔹 Outer Fold 1 — training inner search for Piperacillin_Tazobactam
# ==============================
# Best inner parameters: {'xgb__colsample_bytree': 0.7640664495284486, 'xgb__gamma': 0.4876346704833222, 'xgb__learning_rate': 0.22593042822184672, 'xgb__max_depth': 3, 'xgb__n_estimators': 395, 'xgb__scale_pos_weight': 35.47222222222222, 'xgb__subsample': 0.40261527047497736}
# Best inner score: 0.04368783207037715
#
# ==============================
# 🔹 Outer Fold 2 — training inner search for Piperacillin_Tazobactam
# ==============================
# Best inner parameters: {'xgb__colsample_bytree': 0.5064543369180614, 'xgb__gamma': 0.37173034138371164, 'xgb__learning_rate': 0.20397510005039515, 'xgb__max_depth': 3, 'xgb__n_estimators': 328, 'xgb__scale_pos_weight': 17.73611111111111, 'xgb__subsample': 0.9821047615363967}
# Best inner score: 0.02919275191636191
#
# ==============================
# 🔹 Outer Fold 3 — training inner search for Piperacillin_Tazobactam
# ==============================
# Best inner parameters: {'xgb__colsample_bytree': 0.36140088883284394, 'xgb__gamma': 0.7833955197168099, 'xgb__learning_rate': 0.06769303305937369, 'xgb__max_depth': 3, 'xgb__n_estimators': 361, 'xgb__scale_pos_weight': 53.20833333333333, 'xgb__subsample': 0.7799962261085898}
# Best inner score: 0.014706872648049119
#
# ==============================
# 🔹 Outer Fold 4 — training inner search for Piperacillin_Tazobactam
# ==============================
# Best inner parameters: {'xgb__colsample_bytree': 0.5064543369180614, 'xgb__gamma': 0.37173034138371164, 'xgb__learning_rate': 0.20397510005039515, 'xgb__max_depth': 3, 'xgb__n_estimators': 328, 'xgb__scale_pos_weight': 17.73611111111111, 'xgb__subsample': 0.9821047615363967}
# Best inner score: 0.03745018748080598
#
# ==============================
# 🔹 Outer Fold 5 — training inner search for Piperacillin_Tazobactam
# ==============================
# Best inner parameters: {'xgb__colsample_bytree': 0.5064543369180614, 'xgb__gamma': 0.37173034138371164, 'xgb__learning_rate': 0.20397510005039515, 'xgb__max_depth': 3, 'xgb__n_estimators': 328, 'xgb__scale_pos_weight': 17.73611111111111, 'xgb__subsample': 0.9821047615363967}
# Best inner score: 0.06441688019256153
#
#
# ===== Nested CV Summary for Piperacillin_Tazobactam=====
#    fold    recall        f1       FNR
# 0     1  0.111111  0.944877  0.888889
# 1     2  0.000000  0.965897  1.000000
# 2     3  0.222222  0.904290  0.777778
# 3     4  0.055556  0.966802  0.944444
# 4     5  0.000000  0.961516  1.000000
# Mean Accuracy: 0.9274131274131274
# Mean Recall: 0.07777777777777777
# Mean F1: 0.9486763572902172
# Mean false negative rate: 0.9222222222222222
# Saved results to results_Piperacillin_Tazobactam.csv
#
# ==============================
# 🔹 Outer Fold 1 — training inner search for Levofloxacin
# ==============================
# Best inner parameters: {'xgb__colsample_bytree': 0.36140088883284394, 'xgb__gamma': 0.7833955197168099, 'xgb__learning_rate': 0.06769303305937369, 'xgb__max_depth': 3, 'xgb__n_estimators': 361, 'xgb__scale_pos_weight': 4.006366307541626, 'xgb__subsample': 0.7799962261085898}
# Best inner score: 0.2564469776690499
#
# ==============================
# 🔹 Outer Fold 2 — training inner search for Levofloxacin
# ==============================
# Best inner parameters: {'xgb__colsample_bytree': 0.36140088883284394, 'xgb__gamma': 0.7833955197168099, 'xgb__learning_rate': 0.06769303305937369, 'xgb__max_depth': 3, 'xgb__n_estimators': 361, 'xgb__scale_pos_weight': 4.006366307541626, 'xgb__subsample': 0.7799962261085898}
# Best inner score: 0.27553886997509963
#
# ==============================
# 🔹 Outer Fold 3 — training inner search for Levofloxacin
# ==============================
# Best inner parameters: {'xgb__colsample_bytree': 0.36140088883284394, 'xgb__gamma': 0.7833955197168099, 'xgb__learning_rate': 0.06769303305937369, 'xgb__max_depth': 3, 'xgb__n_estimators': 361, 'xgb__scale_pos_weight': 4.006366307541626, 'xgb__subsample': 0.7799962261085898}
# Best inner score: 0.2549061954953844
#
# ==============================
# 🔹 Outer Fold 4 — training inner search for Levofloxacin
# ==============================
# Best inner parameters: {'xgb__colsample_bytree': 0.9840134829675653, 'xgb__gamma': 1.0440636313297216, 'xgb__learning_rate': 0.17903579482489707, 'xgb__max_depth': 4, 'xgb__n_estimators': 371, 'xgb__scale_pos_weight': 5.341821743388834, 'xgb__subsample': 0.3821561339972655}
# Best inner score: 0.2704658690314918
#
# ==============================
# 🔹 Outer Fold 5 — training inner search for Levofloxacin
# ==============================
# Best inner parameters: {'xgb__colsample_bytree': 0.36140088883284394, 'xgb__gamma': 0.7833955197168099, 'xgb__learning_rate': 0.06769303305937369, 'xgb__max_depth': 3, 'xgb__n_estimators': 361, 'xgb__scale_pos_weight': 4.006366307541626, 'xgb__subsample': 0.7799962261085898}
# Best inner score: 0.2679112491709839
#
#
# ===== Nested CV Summary for Levofloxacin=====
#    fold    recall        f1       FNR
# 0     1  0.318627  0.759234  0.681373
# 1     2  0.362745  0.734773  0.637255
# 2     3  0.313725  0.739504  0.686275
# 3     4  0.377451  0.678757  0.622549
# 4     5  0.287805  0.748801  0.712195
# Mean Accuracy: 0.7111969111969112
# Mean Recall: 0.33207077953132474
# Mean F1: 0.7322136909676493
# Mean false negative rate: 0.6679292204686753
# Saved results to results_Levofloxacin.csv
#
# ==============================
# 🔹 Outer Fold 1 — training inner search for Ceftriaxone
# ==============================
# Best inner parameters: {'xgb__colsample_bytree': 0.36140088883284394, 'xgb__gamma': 0.7833955197168099, 'xgb__learning_rate': 0.06769303305937369, 'xgb__max_depth': 3, 'xgb__n_estimators': 361, 'xgb__scale_pos_weight': 10.649647887323944, 'xgb__subsample': 0.7799962261085898}
# Best inner score: 0.1340501344479413
#
# ==============================
# 🔹 Outer Fold 2 — training inner search for Ceftriaxone
# ==============================
# Best inner parameters: {'xgb__colsample_bytree': 0.36140088883284394, 'xgb__gamma': 0.7833955197168099, 'xgb__learning_rate': 0.06769303305937369, 'xgb__max_depth': 3, 'xgb__n_estimators': 361, 'xgb__scale_pos_weight': 10.649647887323944, 'xgb__subsample': 0.7799962261085898}
# Best inner score: 0.13638177885812167
#
# ==============================
# 🔹 Outer Fold 3 — training inner search for Ceftriaxone
# ==============================
# Best inner parameters: {'xgb__colsample_bytree': 0.36140088883284394, 'xgb__gamma': 0.7833955197168099, 'xgb__learning_rate': 0.06769303305937369, 'xgb__max_depth': 3, 'xgb__n_estimators': 361, 'xgb__scale_pos_weight': 10.649647887323944, 'xgb__subsample': 0.7799962261085898}
# Best inner score: 0.15095096685912776
#
# ==============================
# 🔹 Outer Fold 4 — training inner search for Ceftriaxone
# ==============================
# Best inner parameters: {'xgb__colsample_bytree': 0.36140088883284394, 'xgb__gamma': 0.7833955197168099, 'xgb__learning_rate': 0.06769303305937369, 'xgb__max_depth': 3, 'xgb__n_estimators': 361, 'xgb__scale_pos_weight': 10.649647887323944, 'xgb__subsample': 0.7799962261085898}
# Best inner score: 0.13208496239229203
#
# ==============================
# 🔹 Outer Fold 5 — training inner search for Ceftriaxone
# ==============================
# Best inner parameters: {'xgb__colsample_bytree': 0.3253524923335095, 'xgb__gamma': 0.1590373696250477, 'xgb__learning_rate': 0.12871575577588695, 'xgb__max_depth': 3, 'xgb__n_estimators': 383, 'xgb__scale_pos_weight': 10.649647887323944, 'xgb__subsample': 0.9135442116320804}
# Best inner score: 0.14071814651074496
#
#
# ===== Nested CV Summary for Ceftriaxone=====
#    fold    recall        f1       FNR
# 0     1  0.317647  0.839900  0.682353
# 1     2  0.258824  0.835645  0.741176
# 2     3  0.235294  0.828291  0.764706
# 3     4  0.235294  0.838479  0.764706
# 4     5  0.232558  0.812970  0.767442
# Mean Accuracy: 0.7891891891891893
# Mean Recall: 0.2559233926128591
# Mean F1: 0.8310570615599782
# Mean false negative rate: 0.744076607387141
# Saved results to results_Ceftriaxone.csv
# Saved all results to all_antibiotics_results.csv
